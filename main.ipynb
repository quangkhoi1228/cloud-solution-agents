# %%
import os
from dotenv import load_dotenv
load_dotenv()  # Mặc định tìm file .env ở thư mục hiện tại

os.environ['FINNHUB_API_KEY'] = os.getenv("FINNHUB_API_KEY")
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")
os.environ['CEREBRAS_API_KEY'] = os.getenv("CEREBRAS_API_KEY")
os.environ['GOOGLE_CUSTOM_SEARCH_API_KEY'] = os.getenv("GOOGLE_CUSTOM_SEARCH_API_KEY")
os.environ['GOOGLE_CUSTOM_SEARCH_ID'] = os.getenv("GOOGLE_CUSTOM_SEARCH_ID")

# %%
from tradingagents.default_config import DEFAULT_CONFIG
from tradingagents.graph.cloud_solution_agent_graph import \
    CloudSolutionAgentsGraph

config = DEFAULT_CONFIG.copy()


config["llm_provider"] = "openai"  # Use a different model
config["deep_think_llm"] = "gpt-4o-mini"  # Use a different model
config["quick_think_llm"] = "gpt-4o-mini"  # Use a different model

ta = None

# Initialize with custom config
ta = CloudSolutionAgentsGraph(debug=True, config=config)

# Memorize mistakes and reflect
# ta.reflect_and_remember(1000) # parameter is the position returns

# %%
from IPython.display import Image, display
try:
    display(Image(ta.graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
# forward propagate
final_state = ta.propagate("Tôi muốn Migrate website của tôi (quangkhoi1228.com) bao gồm 1 website cá nhân dùng Python Django và 1 database PostgreSQL trên 2 máy chủ trong cùng 1 VPC có dung lượng 16CPU 32GB RAM 5TB SSD, 2 IP public lên FCI, dung lượng data khoảng 5Tb không cần firewall, monitoring, logging", 
                          # store_state="full_states_log_2025-07-24.json"
                          )
print(final_state)
# Out:
# ================================ Human Message =================================
#
# Tôi muốn Migrate website của tôi (quangkhoi1228.com) bao gồm 1 website cá nhân dùng Python Django và 1 database PostgreSQL trên 2 máy chủ trong cùng 1 VPC có dung lượng 16CPU 32GB RAM 5TB SSD, 2 IP public lên FCI, dung lượng data khoảng 5Tb không cần firewall, monitoring, logging
# ...

# %%
ta.curr_state
# Out:
# {'messages': [HumanMessage(content='Tôi muốn Migrate website của tôi (quangkhoi1228.com) bao gồm 1 website cá nhân dùng Python Django và 1 database PostgreSQL trên 2 máy chủ trong cùng 1 VPC có dung lượng 16CPU 32GB RAM 5TB SSD, 2 IP public lên FCI, dung lượng data khoảng 5Tb không cần firewall, monitoring, logging', additional_kwargs={}, response_metadata={}, id='87693ac9-2592-4003-b33c-5e256ba91951'),
# ...
